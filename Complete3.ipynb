# %% [markdown]
# <a href="https://colab.research.google.com/github/BelloBer/Landslide-Detection/blob/main/Complete3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Complete3

# %%
# Improved Landslide Detection Model
# Optimized for better F1 scores, precision, and accuracy

from google.colab import drive
drive.mount('/content/drive')

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import f1_score, classification_report, confusion_matrix, roc_auc_score
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Dense, Flatten, Conv2D, MaxPooling2D, Dropout,
                                   BatchNormalization, Input, GlobalAveragePooling2D,
                                   SeparableConv2D, Add, Activation, MultiHeadAttention,
                                   LayerNormalization, Reshape, Concatenate)
from tensorflow.keras import backend as K
from tensorflow.keras.utils import Sequence
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import (ModelCheckpoint, EarlyStopping, ReduceLROnPlateau,
                                       TensorBoard, LearningRateScheduler)
from tensorflow.keras.optimizers import Adam, AdamW
from tensorflow.keras.regularizers import l2
import datetime
import gc
from collections import Counter

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Enable mixed precision for better performance
policy = tf.keras.mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy)

# Define paths
train_data_path = '/content/drive/My Drive/train_data/'
test_data_path = '/content/drive/My Drive/test_data/'
train_csv = "/content/drive/My Drive/train_data/Train.csv"
test_csv = "/content/drive/My Drive/test_data/Test.csv"

# Load and analyze data
train_df = pd.read_csv(train_csv)
print("Dataset Info:")
print(f"Total samples: {len(train_df)}")
print(f"Class distribution:\n{train_df['label'].value_counts()}")
print(f"Class ratio: {train_df['label'].value_counts()[1] / train_df['label'].value_counts()[0]:.3f}")

# Enhanced image loading with better preprocessing
def load_and_preprocess_image(image_id, folder_path, target_size=(256, 256)):
    """Enhanced image loading with better preprocessing for SAR and optical data"""
    try:
        image_path = os.path.join(folder_path, f"{image_id}.npy")
        img = np.load(image_path).astype(np.float32)

        if len(img.shape) != 3 or img.shape[2] != 12:
            print(f"Invalid shape for {image_id}: {img.shape}")
            return None

        # Resize if necessary
        if img.shape[:2] != target_size:
            print(f"Resizing {image_id} from {img.shape[:2]} to {target_size}")
            resized_img = np.zeros((target_size[0], target_size[1], 12), dtype=np.float32)
            for channel in range(12):
                resized_img[:, :, channel] = tf.image.resize(
                    img[:, :, channel:channel+1], target_size
                ).numpy()[:, :, 0]
            img = resized_img

        processed_img = np.zeros_like(img, dtype=np.float32)

        # Process optical bands (0-3) with enhanced normalization
        for band in range(4):
            band_data = img[:, :, band]

            # Remove outliers using percentile clipping
            p2, p98 = np.percentile(band_data, [2, 98])
            band_data = np.clip(band_data, p2, p98)

            # Normalize to [0, 1]
            if band_data.max() > band_data.min():
                processed_img[:, :, band] = (band_data - band_data.min()) / (band_data.max() - band_data.min())
            else:
                processed_img[:, :, band] = 0.5

        # Process SAR bands (4-11) with improved handling
        for band in range(4, 12):
            sar_data = img[:, :, band]

            # Convert to dB scale with better handling of negative values
            sar_linear = np.abs(sar_data) + 1e-10
            sar_db = 10 * np.log10(sar_linear)

            # Clip extreme values
            p1, p99 = np.percentile(sar_db, [1, 99])
            sar_db = np.clip(sar_db, p1, p99)

            # Normalize
            if sar_db.max() > sar_db.min():
                processed_img[:, :, band] = (sar_db - sar_db.min()) / (sar_db.max() - sar_db.min())
            else:
                processed_img[:, :, band] = 0.5

        return processed_img

    except Exception as e:
        print(f"Error loading {image_id}: {str(e)}")
        return None

# Enhanced data generator with custom augmentation for multi-channel images
class EnhancedLandslideGenerator(Sequence):
    def __init__(self, image_ids, labels, folder_path, batch_size=16,
                 augment=False, shuffle=True, mixup_alpha=0.2):
        super().__init__()
        self.image_ids = image_ids
        self.labels = labels
        self.folder_path = folder_path
        self.batch_size = batch_size
        self.augment = augment
        self.shuffle = shuffle
        self.mixup_alpha = mixup_alpha

        # Validate files
        self.valid_indices = self._validate_files()
        print(f"Valid files: {len(self.valid_indices)}/{len(self.image_ids)}")

        self.on_epoch_end()

    def _validate_files(self):
        valid_indices = []
        for idx, img_id in enumerate(self.image_ids):
            file_path = os.path.join(self.folder_path, f"{img_id}.npy")
            if os.path.exists(file_path):
                try:
                    test_img = np.load(file_path)
                    if len(test_img.shape) == 3 and test_img.shape[2] == 12:
                        valid_indices.append(idx)
                except:
                    continue
        return valid_indices

    def __len__(self):
        return int(np.ceil(len(self.valid_indices) / self.batch_size))

    def custom_augment(self, img):
        """Custom augmentation for multi-channel images"""
        if not self.augment:
            return img

        # Random horizontal flip
        if np.random.random() < 0.5:
            img = np.flip(img, axis=1)

        # Random vertical flip
        if np.random.random() < 0.5:
            img = np.flip(img, axis=0)

        # Random rotation (90, 180, 270 degrees)
        if np.random.random() < 0.5:
            k = np.random.randint(1, 4)
            img = np.rot90(img, k=k, axes=(0, 1))

        # Random brightness adjustment (only for optical bands 0-3)
        if np.random.random() < 0.3:
            brightness_factor = np.random.uniform(0.8, 1.2)
            img[:, :, :4] = np.clip(img[:, :, :4] * brightness_factor, 0, 1)

        # Random noise addition
        if np.random.random() < 0.2:
            noise = np.random.normal(0, 0.01, img.shape).astype(np.float32)
            img = np.clip(img + noise, 0, 1)

        # Random translation
        if np.random.random() < 0.3:
            shift_x = np.random.randint(-20, 21)
            shift_y = np.random.randint(-20, 21)
            img = np.roll(img, shift_x, axis=1)
            img = np.roll(img, shift_y, axis=0)

        return img

    def mixup(self, x1, x2, y1, y2, alpha):
        """Apply mixup augmentation"""
        lam = np.random.beta(alpha, alpha)
        mixed_x = lam * x1 + (1 - lam) * x2
        mixed_y = lam * y1 + (1 - lam) * y2
        return mixed_x, mixed_y

    def __getitem__(self, idx):
        batch_indices = self.valid_indices[idx * self.batch_size:(idx + 1) * self.batch_size]

        batch_images = []
        batch_labels = []

        for i in batch_indices:
            img_id = self.image_ids[i]
            label = self.labels[i]

            img = load_and_preprocess_image(img_id, self.folder_path)
            if img is not None:
                # Apply custom augmentation instead of ImageDataGenerator
                img = self.custom_augment(img)
                batch_images.append(img)
                batch_labels.append(label)

        if len(batch_images) == 0:
            batch_images = [np.zeros((256, 256, 12), dtype=np.float32)]
            batch_labels = [0]

        batch_images = np.array(batch_images, dtype=np.float32)
        batch_labels = np.array(batch_labels, dtype=np.float32)

        # Apply mixup for training
        if self.augment and len(batch_images) >= 2 and np.random.random() < 0.3:
            indices = np.random.permutation(len(batch_images))
            mixed_images, mixed_labels = self.mixup(
                batch_images, batch_images[indices],
                batch_labels, batch_labels[indices],
                self.mixup_alpha
            )
            return mixed_images, mixed_labels

        return batch_images, batch_labels

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.valid_indices)

# Enhanced metrics
def balanced_f1_score(y_true, y_pred):
    """Calculate balanced F1 score considering both classes"""
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')

    # F1 for positive class
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    fp = K.sum(K.round(K.clip((1 - y_true) * y_pred, 0, 1)))
    fn = K.sum(K.round(K.clip(y_true * (1 - y_pred), 0, 1)))

    precision_pos = tp / (tp + fp + K.epsilon())
    recall_pos = tp / (tp + fn + K.epsilon())
    f1_pos = 2 * precision_pos * recall_pos / (precision_pos + recall_pos + K.epsilon())

    # F1 for negative class
    tn = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    precision_neg = tn / (tn + fn + K.epsilon())
    recall_neg = tn / (tn + fp + K.epsilon())
    f1_neg = 2 * precision_neg * recall_neg / (precision_neg + recall_neg + K.epsilon())

    # Return macro F1
    return (f1_pos + f1_neg) / 2

def precision_m(y_true, y_pred):
    y_pred = K.round(K.clip(y_pred, 0, 1))
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return tp / (predicted_positives + K.epsilon())

def recall_m(y_true, y_pred):
    y_pred = K.round(K.clip(y_pred, 0, 1))
    tp = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return tp / (possible_positives + K.epsilon())

# Enhanced loss functions
def focal_loss(gamma=2.0, alpha=0.75):
    def focal_loss_fixed(y_true, y_pred):
        y_true = K.cast(y_true, 'float32')
        y_pred = K.cast(K.clip(y_pred, K.epsilon(), 1 - K.epsilon()), 'float32')

        ce_loss = -y_true * K.log(y_pred) - (1 - y_true) * K.log(1 - y_pred)
        p_t = y_true * y_pred + (1 - y_true) * (1 - y_pred)
        focal_weight = alpha * K.pow(1 - p_t, gamma)

        return K.mean(focal_weight * ce_loss)
    return focal_loss_fixed

def combined_loss(y_true, y_pred):
    """Combine focal loss with dice loss for better performance"""
    focal = focal_loss(gamma=2.0, alpha=0.75)(y_true, y_pred)

    # Dice loss component
    smooth = 1e-6
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice_coeff = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    dice_loss = 1 - dice_coeff

    return focal + 0.3 * dice_loss

# Enhanced model architecture with flexible input size
def create_enhanced_model(input_shape):
    """Create an enhanced CNN with attention mechanism"""
    print(f"Creating model with input shape: {input_shape}")
    inputs = Input(shape=input_shape)

    # Initial conv block
    x = Conv2D(32, (3, 3), padding='same', kernel_regularizer=l2(1e-4))(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Residual blocks with increasing complexity
    def residual_block(x, filters, downsample=False):
        shortcut = x
        stride = 2 if downsample else 1

        # Use regular Conv2D for better compatibility
        x = Conv2D(filters, (3, 3), strides=stride, padding='same',
                   kernel_regularizer=l2(1e-4))(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

        x = Conv2D(filters, (3, 3), padding='same',
                   kernel_regularizer=l2(1e-4))(x)
        x = BatchNormalization()(x)

        if downsample or shortcut.shape[-1] != filters:
            shortcut = Conv2D(filters, (1, 1), strides=stride, padding='same',
                             kernel_regularizer=l2(1e-4))(shortcut)
            shortcut = BatchNormalization()(shortcut)

        x = Add()([x, shortcut])
        x = Activation('relu')(x)
        x = Dropout(0.1)(x)

        return x

    # Adaptive feature extraction based on input size
    current_size = input_shape[0]  # Assume square images

    if current_size >= 256:
        # Full architecture for large images
        x = residual_block(x, 64, downsample=True)   # /2
        x = residual_block(x, 64)
        x = residual_block(x, 128, downsample=True)  # /4
        x = residual_block(x, 128)
        x = residual_block(x, 256, downsample=True)  # /8
        x = residual_block(x, 256)
        x = residual_block(x, 512, downsample=True)  # /16
    elif current_size >= 128:
        # Medium architecture
        x = residual_block(x, 64, downsample=True)   # /2
        x = residual_block(x, 128, downsample=True)  # /4
        x = residual_block(x, 256, downsample=True)  # /8
        x = residual_block(x, 512, downsample=True)  # /16
    else:
        # Smaller architecture for small images
        x = residual_block(x, 64, downsample=True)   # /2
        x = residual_block(x, 128, downsample=True)  # /4
        x = residual_block(x, 256)

    # Simplified attention mechanism (remove if causing issues)
    try:
        # Get current spatial dimensions
        spatial_dims = x.shape[1] * x.shape[2]
        channels = x.shape[3]

        # Only apply attention if we have reasonable dimensions
        if spatial_dims > 4 and spatial_dims < 1024:
            # Reshape for attention
            x_reshaped = Reshape((spatial_dims, channels))(x)

            # Multi-head attention with reduced complexity
            attention_output = MultiHeadAttention(
                num_heads=min(8, channels // 8),
                key_dim=min(64, channels // 4),
                dropout=0.1
            )(x_reshaped, x_reshaped)

            attention_output = LayerNormalization()(attention_output + x_reshaped)

            # Reshape back
            x_attended = Reshape((x.shape[1], x.shape[2], channels))(attention_output)

            # Combine original and attended features
            x = Concatenate()([x, x_attended])

    except Exception as e:
        print(f"Attention mechanism failed, using standard processing: {e}")
        # Fallback to standard processing
        pass

    # Final processing
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(256, activation='relu', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    outputs = Dense(1, activation='sigmoid', dtype='float32', name='predictions')(x)

    model = Model(inputs, outputs)
    return model

# Prepare data with stratified split
train_idx, val_idx = train_test_split(
    np.arange(len(train_df)),
    test_size=0.2,
    random_state=42,
    stratify=train_df['label']
)

# Calculate class weights
class_weights = compute_class_weight(
    'balanced',
    classes=np.unique(train_df['label']),
    y=train_df['label']
)
class_weight_dict = {i: class_weights[i] for i in range(len(class_weights))}
print(f"Class weights: {class_weight_dict}")

# Create generators
train_gen = EnhancedLandslideGenerator(
    image_ids=train_df['ID'].values[train_idx],
    labels=train_df['label'].values[train_idx],
    folder_path=train_data_path,
    batch_size=8,  # Smaller batch for better convergence
    augment=True,
    mixup_alpha=0.2
)

val_gen = EnhancedLandslideGenerator(
    image_ids=train_df['ID'].values[val_idx],
    labels=train_df['label'].values[val_idx],
    folder_path=train_data_path,
    batch_size=8,
    augment=False
)

# Test a batch to check shapes
print("Testing data generators...")
try:
    test_batch_x, test_batch_y = train_gen[0]
    print(f"Train batch shape: {test_batch_x.shape}")
    print(f"Train labels shape: {test_batch_y.shape}")

    val_batch_x, val_batch_y = val_gen[0]
    print(f"Val batch shape: {val_batch_x.shape}")
    print(f"Val labels shape: {val_batch_y.shape}")

    # Update model input shape based on actual data
    actual_shape = test_batch_x.shape[1:]
    print(f"Creating model with input shape: {actual_shape}")

except Exception as e:
    print(f"Error testing generators: {e}")
    # Use default shape if testing fails
    actual_shape = (256, 256, 12)

# Create and compile model with correct input shape
model = create_enhanced_model(actual_shape)

# Use AdamW optimizer with cosine decay
initial_learning_rate = 1e-3
lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=initial_learning_rate,
    decay_steps=len(train_gen) * 30,
    alpha=1e-6
)

optimizer = AdamW(learning_rate=lr_schedule, weight_decay=1e-4)

model.compile(
    optimizer=optimizer,
    loss=combined_loss,
    metrics=['accuracy', precision_m, recall_m, balanced_f1_score]
)

print(f"Model parameters: {model.count_params():,}")

# Enhanced callbacks
callbacks = [
    ModelCheckpoint(
        filepath='best_landslide_model.keras',
        monitor='val_balanced_f1_score',
        mode='max',
        save_best_only=True,
        verbose=1
    ),
    EarlyStopping(
        monitor='val_balanced_f1_score',
        mode='max',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_balanced_f1_score',
        mode='max',
        factor=0.5,
        patience=7,
        min_lr=1e-7,
        verbose=1
    )
]

# Train model
print("Starting training...")
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=50,
    callbacks=callbacks,
    class_weight=class_weight_dict,
    verbose=1
)

# Load best model
model.load_weights('best_landslide_model.keras')

# Enhanced threshold optimization
print("Optimizing decision threshold...")
val_predictions = []
val_labels = []

for i in range(len(val_gen)):
    batch_x, batch_y = val_gen[i]
    pred_batch = model.predict(batch_x, verbose=0)
    val_predictions.extend(pred_batch.flatten())
    val_labels.extend(batch_y.flatten())

y_probs = np.array(val_predictions)
y_true = np.array(val_labels)

# Grid search for optimal threshold
thresholds = np.arange(0.1, 0.9, 0.005)
best_f1 = 0
best_thresh = 0.5
best_metrics = {}

for thresh in thresholds:
    y_pred = (y_probs > thresh).astype(int)

    # Calculate metrics for both classes
    f1_macro = f1_score(y_true, y_pred, average='macro')
    f1_pos = f1_score(y_true, y_pred, pos_label=1)
    f1_neg = f1_score(y_true, y_pred, pos_label=0)

    # Optimize for balanced performance
    balanced_score = f1_macro * 0.6 + min(f1_pos, f1_neg) * 0.4

    if balanced_score > best_f1:
        best_f1 = balanced_score
        best_thresh = thresh
        best_metrics = {
            'f1_macro': f1_macro,
            'f1_positive': f1_pos,
            'f1_negative': f1_neg,
            'balanced_score': balanced_score
        }

print(f"\nOptimal threshold: {best_thresh:.3f}")
print(f"Best metrics: {best_metrics}")

# Final evaluation
y_pred_final = (y_probs > best_thresh).astype(int)
print(f"\nFinal Classification Report:")
print(classification_report(y_true, y_pred_final,
                          target_names=['No Landslide', 'Landslide']))

# Generate test predictions
print("Generating test predictions...")
test_df = pd.read_csv(test_csv)
test_predictions = []

batch_size = 16
for i in range(0, len(test_df), batch_size):
    batch_ids = test_df['ID'].values[i:i+batch_size]
    batch_imgs = []

    for img_id in batch_ids:
        img = load_and_preprocess_image(img_id, test_data_path)
        if img is not None:
            batch_imgs.append(img)
        else:
            batch_imgs.append(np.zeros((256, 256, 12), dtype=np.float32))

    batch_imgs = np.array(batch_imgs)
    probs = model.predict(batch_imgs, verbose=0).flatten()
    preds = (probs > best_thresh).astype(int)
    test_predictions.extend(preds)

# Create submission
submission_df = pd.DataFrame({
    'ID': test_df['ID'],
    'label': test_predictions
})

submission_df.to_csv('Enhanced_Landslide_Submission.csv', index=False)
print(f"Submission saved! Prediction distribution: {Counter(test_predictions)}")

# Cleanup
gc.collect()
print("Training completed successfully!")
# Out:
# Streaming output truncated to the last 5000 lines.
# Resizing ID_51S3M4 from (64, 64) to (256, 256)
# 500/715 ━━━━━━━━━━━━━━━━━━━━ 1:59 555ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4675 - loss: 0.6110 - precision_m: 1.2067 - recall_m: 1.1449Resizing ID_N3ZB67 from (64, 64) to (256, 256)
# Resizing ID_Y20KZC from (64, 64) to (256, 256)
# Resizing ID_8SAUMJ from (64, 64) to (256, 256)
# Resizing ID_OARV3X from (64, 64) to (256, 256)
# Resizing ID_ZZFZPA from (64, 64) to (256, 256)
# Resizing ID_NE7IS5 from (64, 64) to (256, 256)
# Resizing ID_R0N53D from (64, 64) to (256, 256)
# Resizing ID_PU2BAY from (64, 64) to (256, 256)
# 501/715 ━━━━━━━━━━━━━━━━━━━━ 1:58 555ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4675 - loss: 0.6110 - precision_m: 1.2069 - recall_m: 1.1453Resizing ID_CI00OX from (64, 64) to (256, 256)
# Resizing ID_Q1BLPW from (64, 64) to (256, 256)
# Resizing ID_SPQ8NS from (64, 64) to (256, 256)
# Resizing ID_540P57 from (64, 64) to (256, 256)
# Resizing ID_M0YJD0 from (64, 64) to (256, 256)
# Resizing ID_20JCQV from (64, 64) to (256, 256)
# Resizing ID_B4H0AH from (64, 64) to (256, 256)
# Resizing ID_ED8LI7 from (64, 64) to (256, 256)
# 502/715 ━━━━━━━━━━━━━━━━━━━━ 1:58 555ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4675 - loss: 0.6110 - precision_m: 1.2071 - recall_m: 1.1456Resizing ID_5UC1A6 from (64, 64) to (256, 256)
# Resizing ID_5XHZ96 from (64, 64) to (256, 256)
# Resizing ID_MWRAML from (64, 64) to (256, 256)
# Resizing ID_68P9EW from (64, 64) to (256, 256)
# Resizing ID_OIJP43 from (64, 64) to (256, 256)
# Resizing ID_SCQVJN from (64, 64) to (256, 256)
# Resizing ID_J6JDKI from (64, 64) to (256, 256)
# Resizing ID_2MFNPV from (64, 64) to (256, 256)
# 503/715 ━━━━━━━━━━━━━━━━━━━━ 1:57 555ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4675 - loss: 0.6109 - precision_m: 1.2073 - recall_m: 1.1460Resizing ID_5C043X from (64, 64) to (256, 256)
# Resizing ID_5RWNZO from (64, 64) to (256, 256)
# Resizing ID_8YQGKB from (64, 64) to (256, 256)
# Resizing ID_2OGQO7 from (64, 64) to (256, 256)
# Resizing ID_N990QU from (64, 64) to (256, 256)
# Resizing ID_J40ULE from (64, 64) to (256, 256)
# Resizing ID_6SKSGL from (64, 64) to (256, 256)
# Resizing ID_2FJQC6 from (64, 64) to (256, 256)
# 504/715 ━━━━━━━━━━━━━━━━━━━━ 1:57 555ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4675 - loss: 0.6109 - precision_m: 1.2075 - recall_m: 1.1464Resizing ID_XTZXEI from (64, 64) to (256, 256)
# Resizing ID_91LLZ6 from (64, 64) to (256, 256)
# Resizing ID_CTKHP0 from (64, 64) to (256, 256)
# Resizing ID_38YM37 from (64, 64) to (256, 256)
# Resizing ID_2GO8JE from (64, 64) to (256, 256)
# Resizing ID_I0R9OX from (64, 64) to (256, 256)
# Resizing ID_J0TZT9 from (64, 64) to (256, 256)
# Resizing ID_WDUBAK from (64, 64) to (256, 256)
# 505/715 ━━━━━━━━━━━━━━━━━━━━ 1:56 555ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4675 - loss: 0.6108 - precision_m: 1.2077 - recall_m: 1.1467Resizing ID_9PNMSC from (64, 64) to (256, 256)
# Resizing ID_SRVNF1 from (64, 64) to (256, 256)
# Resizing ID_NO7AB6 from (64, 64) to (256, 256)
# Resizing ID_STD4VJ from (64, 64) to (256, 256)
# Resizing ID_UD701F from (64, 64) to (256, 256)
# Resizing ID_VTBXSZ from (64, 64) to (256, 256)
# Resizing ID_BHIUNM from (64, 64) to (256, 256)
# Resizing ID_QJGJ6B from (64, 64) to (256, 256)
# 506/715 ━━━━━━━━━━━━━━━━━━━━ 1:55 555ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4675 - loss: 0.6108 - precision_m: 1.2079 - recall_m: 1.1471Resizing ID_CQ8VWZ from (64, 64) to (256, 256)
# Resizing ID_1LFUGZ from (64, 64) to (256, 256)
# Resizing ID_B0YIQP from (64, 64) to (256, 256)
# Resizing ID_QUTKMA from (64, 64) to (256, 256)
# Resizing ID_GCMG8U from (64, 64) to (256, 256)
# Resizing ID_V6TS8K from (64, 64) to (256, 256)
# Resizing ID_0BNC3T from (64, 64) to (256, 256)
# Resizing ID_SIPP8I from (64, 64) to (256, 256)
# 507/715 ━━━━━━━━━━━━━━━━━━━━ 1:55 555ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4676 - loss: 0.6107 - precision_m: 1.2081 - recall_m: 1.1475Resizing ID_Y994JU from (64, 64) to (256, 256)
# Resizing ID_5R2H3V from (64, 64) to (256, 256)
# Resizing ID_LBZHY8 from (64, 64) to (256, 256)
# Resizing ID_6EEHDV from (64, 64) to (256, 256)
# Resizing ID_7K76RW from (64, 64) to (256, 256)
# Resizing ID_VFN43S from (64, 64) to (256, 256)
# Resizing ID_V2GIUA from (64, 64) to (256, 256)
# Resizing ID_0XQQY8 from (64, 64) to (256, 256)
# 508/715 ━━━━━━━━━━━━━━━━━━━━ 1:54 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4676 - loss: 0.6107 - precision_m: 1.2083 - recall_m: 1.1478Resizing ID_TDZ35E from (64, 64) to (256, 256)
# Resizing ID_KP9T9R from (64, 64) to (256, 256)
# Resizing ID_I4XVAA from (64, 64) to (256, 256)
# Resizing ID_A9NKDG from (64, 64) to (256, 256)
# Resizing ID_VJ45EY from (64, 64) to (256, 256)
# Resizing ID_WCJA7P from (64, 64) to (256, 256)
# Resizing ID_JBGRRM from (64, 64) to (256, 256)
# Resizing ID_OGQKG4 from (64, 64) to (256, 256)
# 509/715 ━━━━━━━━━━━━━━━━━━━━ 1:54 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4676 - loss: 0.6107 - precision_m: 1.2086 - recall_m: 1.1482Resizing ID_QPZ12E from (64, 64) to (256, 256)
# Resizing ID_EG2HR8 from (64, 64) to (256, 256)
# Resizing ID_VLBD78 from (64, 64) to (256, 256)
# Resizing ID_V0GBE6 from (64, 64) to (256, 256)
# Resizing ID_3AOU70 from (64, 64) to (256, 256)
# Resizing ID_EMI2M1 from (64, 64) to (256, 256)
# Resizing ID_I66L4O from (64, 64) to (256, 256)
# Resizing ID_GT0LYA from (64, 64) to (256, 256)
# 510/715 ━━━━━━━━━━━━━━━━━━━━ 1:53 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4676 - loss: 0.6106 - precision_m: 1.2088 - recall_m: 1.1485Resizing ID_BROJZF from (64, 64) to (256, 256)
# Resizing ID_1FBYUM from (64, 64) to (256, 256)
# Resizing ID_0UM3WU from (64, 64) to (256, 256)
# Resizing ID_S7A0OG from (64, 64) to (256, 256)
# Resizing ID_09KU6G from (64, 64) to (256, 256)
# Resizing ID_VWHV40 from (64, 64) to (256, 256)
# Resizing ID_3O0E2A from (64, 64) to (256, 256)
# Resizing ID_UV9G6K from (64, 64) to (256, 256)
# 511/715 ━━━━━━━━━━━━━━━━━━━━ 1:53 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4676 - loss: 0.6106 - precision_m: 1.2090 - recall_m: 1.1489Resizing ID_48X8JT from (64, 64) to (256, 256)
# Resizing ID_X71014 from (64, 64) to (256, 256)
# Resizing ID_3BXKUS from (64, 64) to (256, 256)
# Resizing ID_3KSXSA from (64, 64) to (256, 256)
# Resizing ID_AALBD7 from (64, 64) to (256, 256)
# Resizing ID_C8YASX from (64, 64) to (256, 256)
# Resizing ID_E74QI8 from (64, 64) to (256, 256)
# Resizing ID_KU78MI from (64, 64) to (256, 256)
# 512/715 ━━━━━━━━━━━━━━━━━━━━ 1:52 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4676 - loss: 0.6105 - precision_m: 1.2092 - recall_m: 1.1493Resizing ID_MOQPP2 from (64, 64) to (256, 256)
# Resizing ID_5LOLUC from (64, 64) to (256, 256)
# Resizing ID_EVC1AI from (64, 64) to (256, 256)
# Resizing ID_W9LHQY from (64, 64) to (256, 256)
# Resizing ID_OX5FLL from (64, 64) to (256, 256)
# Resizing ID_QR62PC from (64, 64) to (256, 256)
# Resizing ID_6OR9ZY from (64, 64) to (256, 256)
# Resizing ID_NBS7QG from (64, 64) to (256, 256)
# 513/715 ━━━━━━━━━━━━━━━━━━━━ 1:51 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4676 - loss: 0.6105 - precision_m: 1.2094 - recall_m: 1.1496Resizing ID_MN2Y9F from (64, 64) to (256, 256)
# Resizing ID_IW1C92 from (64, 64) to (256, 256)
# Resizing ID_K4MFRF from (64, 64) to (256, 256)
# Resizing ID_Y7XVPT from (64, 64) to (256, 256)
# Resizing ID_NV6089 from (64, 64) to (256, 256)
# Resizing ID_S09QKH from (64, 64) to (256, 256)
# Resizing ID_48BXUX from (64, 64) to (256, 256)
# Resizing ID_0EK0OJ from (64, 64) to (256, 256)
# 514/715 ━━━━━━━━━━━━━━━━━━━━ 1:51 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4676 - loss: 0.6104 - precision_m: 1.2096 - recall_m: 1.1500Resizing ID_656OFZ from (64, 64) to (256, 256)
# Resizing ID_286W35 from (64, 64) to (256, 256)
# Resizing ID_B7AMEA from (64, 64) to (256, 256)
# Resizing ID_EIC1T4 from (64, 64) to (256, 256)
# Resizing ID_6K6IYX from (64, 64) to (256, 256)
# Resizing ID_MYDT6L from (64, 64) to (256, 256)
# Resizing ID_VAOZA4 from (64, 64) to (256, 256)
# Resizing ID_NQ3HVO from (64, 64) to (256, 256)
# 515/715 ━━━━━━━━━━━━━━━━━━━━ 1:50 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4676 - loss: 0.6104 - precision_m: 1.2098 - recall_m: 1.1504Resizing ID_REPZLW from (64, 64) to (256, 256)
# Resizing ID_VK5IY6 from (64, 64) to (256, 256)
# Resizing ID_7VS0H9 from (64, 64) to (256, 256)
# Resizing ID_7JZ3B1 from (64, 64) to (256, 256)
# Resizing ID_N3851J from (64, 64) to (256, 256)
# Resizing ID_VUSY8T from (64, 64) to (256, 256)
# Resizing ID_N8NR6D from (64, 64) to (256, 256)
# Resizing ID_8AFLU9 from (64, 64) to (256, 256)
# 516/715 ━━━━━━━━━━━━━━━━━━━━ 1:50 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4676 - loss: 0.6103 - precision_m: 1.2100 - recall_m: 1.1508Resizing ID_2NBY8B from (64, 64) to (256, 256)
# Resizing ID_TWLTPF from (64, 64) to (256, 256)
# Resizing ID_MSKPH5 from (64, 64) to (256, 256)
# Resizing ID_ME9HEU from (64, 64) to (256, 256)
# Resizing ID_GOW1Z1 from (64, 64) to (256, 256)
# Resizing ID_R0DXA6 from (64, 64) to (256, 256)
# Resizing ID_WH7DZ3 from (64, 64) to (256, 256)
# Resizing ID_Y56KW6 from (64, 64) to (256, 256)
# 517/715 ━━━━━━━━━━━━━━━━━━━━ 1:49 555ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4676 - loss: 0.6103 - precision_m: 1.2102 - recall_m: 1.1511Resizing ID_MAJP13 from (64, 64) to (256, 256)
# Resizing ID_GRY2ZX from (64, 64) to (256, 256)
# Resizing ID_K5RX1R from (64, 64) to (256, 256)
# Resizing ID_PF42WF from (64, 64) to (256, 256)
# Resizing ID_9S8Y9Z from (64, 64) to (256, 256)
# Resizing ID_MIFKQY from (64, 64) to (256, 256)
# Resizing ID_LRFWIJ from (64, 64) to (256, 256)
# Resizing ID_PQTTRN from (64, 64) to (256, 256)
# 518/715 ━━━━━━━━━━━━━━━━━━━━ 1:49 555ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4676 - loss: 0.6103 - precision_m: 1.2104 - recall_m: 1.1515Resizing ID_A3H0QP from (64, 64) to (256, 256)
# Resizing ID_ZQ8ZCH from (64, 64) to (256, 256)
# Resizing ID_5U84RO from (64, 64) to (256, 256)
# Resizing ID_MU94RQ from (64, 64) to (256, 256)
# Resizing ID_NCQFOI from (64, 64) to (256, 256)
# Resizing ID_GMWZA0 from (64, 64) to (256, 256)
# Resizing ID_DJM4TE from (64, 64) to (256, 256)
# Resizing ID_XBP5BU from (64, 64) to (256, 256)
# 519/715 ━━━━━━━━━━━━━━━━━━━━ 1:48 555ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4676 - loss: 0.6102 - precision_m: 1.2106 - recall_m: 1.1518Resizing ID_CFJXUT from (64, 64) to (256, 256)
# Resizing ID_093HJ3 from (64, 64) to (256, 256)
# Resizing ID_GHJ00R from (64, 64) to (256, 256)
# Resizing ID_HGFA2M from (64, 64) to (256, 256)
# Resizing ID_SLNOQJ from (64, 64) to (256, 256)
# Resizing ID_S8DAP2 from (64, 64) to (256, 256)
# Resizing ID_ABE8OF from (64, 64) to (256, 256)
# Resizing ID_I9YJZ1 from (64, 64) to (256, 256)
# 520/715 ━━━━━━━━━━━━━━━━━━━━ 1:48 555ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4676 - loss: 0.6102 - precision_m: 1.2108 - recall_m: 1.1522Resizing ID_58A901 from (64, 64) to (256, 256)
# Resizing ID_BOODMS from (64, 64) to (256, 256)
# Resizing ID_NNQYGB from (64, 64) to (256, 256)
# Resizing ID_MX9DTT from (64, 64) to (256, 256)
# Resizing ID_P2J7T7 from (64, 64) to (256, 256)
# Resizing ID_BFTRUR from (64, 64) to (256, 256)
# Resizing ID_2FXKX1 from (64, 64) to (256, 256)
# Resizing ID_3700RZ from (64, 64) to (256, 256)
# 521/715 ━━━━━━━━━━━━━━━━━━━━ 1:47 555ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4676 - loss: 0.6101 - precision_m: 1.2110 - recall_m: 1.1525Resizing ID_85S02N from (64, 64) to (256, 256)
# Resizing ID_HYVL4E from (64, 64) to (256, 256)
# Resizing ID_IX6708 from (64, 64) to (256, 256)
# Resizing ID_3ULYAR from (64, 64) to (256, 256)
# Resizing ID_V4N8EA from (64, 64) to (256, 256)
# Resizing ID_TPV0FC from (64, 64) to (256, 256)
# Resizing ID_N3IBD1 from (64, 64) to (256, 256)
# Resizing ID_9P9BVI from (64, 64) to (256, 256)
# 522/715 ━━━━━━━━━━━━━━━━━━━━ 1:47 555ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4676 - loss: 0.6101 - precision_m: 1.2112 - recall_m: 1.1529Resizing ID_2ZVYPQ from (64, 64) to (256, 256)
# Resizing ID_1ORZA7 from (64, 64) to (256, 256)
# Resizing ID_EEOZ9Y from (64, 64) to (256, 256)
# Resizing ID_TMSJ0B from (64, 64) to (256, 256)
# Resizing ID_YBZ0V8 from (64, 64) to (256, 256)
# Resizing ID_QBZDMO from (64, 64) to (256, 256)
# Resizing ID_A3P36I from (64, 64) to (256, 256)
# Resizing ID_572NB6 from (64, 64) to (256, 256)
# 523/715 ━━━━━━━━━━━━━━━━━━━━ 1:46 555ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4676 - loss: 0.6100 - precision_m: 1.2114 - recall_m: 1.1532Resizing ID_2ACL1J from (64, 64) to (256, 256)
# Resizing ID_1CAJ7F from (64, 64) to (256, 256)
# Resizing ID_VWU1TO from (64, 64) to (256, 256)
# Resizing ID_TXDIHJ from (64, 64) to (256, 256)
# Resizing ID_JATAK1 from (64, 64) to (256, 256)
# Resizing ID_SZNIAM from (64, 64) to (256, 256)
# Resizing ID_OOMFPV from (64, 64) to (256, 256)
# Resizing ID_4QJF11 from (64, 64) to (256, 256)
# 524/715 ━━━━━━━━━━━━━━━━━━━━ 1:45 555ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4676 - loss: 0.6100 - precision_m: 1.2116 - recall_m: 1.1536Resizing ID_6KW6H0 from (64, 64) to (256, 256)
# Resizing ID_81CCTX from (64, 64) to (256, 256)
# Resizing ID_HS3RBB from (64, 64) to (256, 256)
# Resizing ID_4P0BTW from (64, 64) to (256, 256)
# Resizing ID_5WC1B2 from (64, 64) to (256, 256)
# Resizing ID_5HS2RZ from (64, 64) to (256, 256)
# Resizing ID_QOOV4U from (64, 64) to (256, 256)
# Resizing ID_C60KH6 from (64, 64) to (256, 256)
# 525/715 ━━━━━━━━━━━━━━━━━━━━ 1:45 555ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4676 - loss: 0.6099 - precision_m: 1.2118 - recall_m: 1.1540Resizing ID_R8QMPB from (64, 64) to (256, 256)
# Resizing ID_C0RW46 from (64, 64) to (256, 256)
# Resizing ID_6PBJ85 from (64, 64) to (256, 256)
# Resizing ID_FEVMOC from (64, 64) to (256, 256)
# Resizing ID_1WU2PD from (64, 64) to (256, 256)
# Resizing ID_AE8IS5 from (64, 64) to (256, 256)
# Resizing ID_OUMADW from (64, 64) to (256, 256)
# Resizing ID_JKQB6L from (64, 64) to (256, 256)
# 526/715 ━━━━━━━━━━━━━━━━━━━━ 1:44 555ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6099 - precision_m: 1.2120 - recall_m: 1.1543Resizing ID_YG50J0 from (64, 64) to (256, 256)
# Resizing ID_J6QJ6T from (64, 64) to (256, 256)
# Resizing ID_WR68WZ from (64, 64) to (256, 256)
# Resizing ID_0TLHEK from (64, 64) to (256, 256)
# Resizing ID_K2705I from (64, 64) to (256, 256)
# Resizing ID_TCOEHH from (64, 64) to (256, 256)
# Resizing ID_ABCRQB from (64, 64) to (256, 256)
# Resizing ID_8PNY2W from (64, 64) to (256, 256)
# 527/715 ━━━━━━━━━━━━━━━━━━━━ 1:44 555ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6099 - precision_m: 1.2122 - recall_m: 1.1547Resizing ID_ACKAJT from (64, 64) to (256, 256)
# Resizing ID_ZOMN1P from (64, 64) to (256, 256)
# Resizing ID_YRLSYM from (64, 64) to (256, 256)
# Resizing ID_3LGDXH from (64, 64) to (256, 256)
# Resizing ID_LBV0HG from (64, 64) to (256, 256)
# Resizing ID_IAVKGS from (64, 64) to (256, 256)
# Resizing ID_W7LWSO from (64, 64) to (256, 256)
# Resizing ID_62RG8M from (64, 64) to (256, 256)
# 528/715 ━━━━━━━━━━━━━━━━━━━━ 1:43 555ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6098 - precision_m: 1.2124 - recall_m: 1.1550Resizing ID_RMNUIA from (64, 64) to (256, 256)
# Resizing ID_K0HU6N from (64, 64) to (256, 256)
# Resizing ID_27V7I4 from (64, 64) to (256, 256)
# Resizing ID_0T6665 from (64, 64) to (256, 256)
# Resizing ID_SZR9D2 from (64, 64) to (256, 256)
# Resizing ID_DW0NG6 from (64, 64) to (256, 256)
# Resizing ID_6R21Q4 from (64, 64) to (256, 256)
# Resizing ID_VC5TDS from (64, 64) to (256, 256)
# 529/715 ━━━━━━━━━━━━━━━━━━━━ 1:43 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6098 - precision_m: 1.2126 - recall_m: 1.1554Resizing ID_7YSPKC from (64, 64) to (256, 256)
# Resizing ID_PHLOD4 from (64, 64) to (256, 256)
# Resizing ID_2X6XR7 from (64, 64) to (256, 256)
# Resizing ID_FQ4042 from (64, 64) to (256, 256)
# Resizing ID_YOU8MX from (64, 64) to (256, 256)
# Resizing ID_KEXG2Y from (64, 64) to (256, 256)
# Resizing ID_HRCIJR from (64, 64) to (256, 256)
# Resizing ID_5SH075 from (64, 64) to (256, 256)
# 530/715 ━━━━━━━━━━━━━━━━━━━━ 1:42 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6097 - precision_m: 1.2128 - recall_m: 1.1557Resizing ID_YQ1BPN from (64, 64) to (256, 256)
# Resizing ID_MH7A3B from (64, 64) to (256, 256)
# Resizing ID_CFUBW7 from (64, 64) to (256, 256)
# Resizing ID_QG51PN from (64, 64) to (256, 256)
# Resizing ID_7GHOOZ from (64, 64) to (256, 256)
# Resizing ID_DLO78T from (64, 64) to (256, 256)
# Resizing ID_4SCMO1 from (64, 64) to (256, 256)
# Resizing ID_FTX35T from (64, 64) to (256, 256)
# 531/715 ━━━━━━━━━━━━━━━━━━━━ 1:41 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6097 - precision_m: 1.2130 - recall_m: 1.1561Resizing ID_RN9OHR from (64, 64) to (256, 256)
# Resizing ID_XKBH0X from (64, 64) to (256, 256)
# Resizing ID_CHQUEK from (64, 64) to (256, 256)
# Resizing ID_BMTPUY from (64, 64) to (256, 256)
# Resizing ID_C4TZQA from (64, 64) to (256, 256)
# Resizing ID_K45WOE from (64, 64) to (256, 256)
# Resizing ID_BZQPQS from (64, 64) to (256, 256)
# Resizing ID_4YVOXZ from (64, 64) to (256, 256)
# 532/715 ━━━━━━━━━━━━━━━━━━━━ 1:41 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6096 - precision_m: 1.2131 - recall_m: 1.1565Resizing ID_2ABWG0 from (64, 64) to (256, 256)
# Resizing ID_EEKBVB from (64, 64) to (256, 256)
# Resizing ID_08V9CO from (64, 64) to (256, 256)
# Resizing ID_ZP8I9H from (64, 64) to (256, 256)
# Resizing ID_F8MQ9A from (64, 64) to (256, 256)
# Resizing ID_2BD7MM from (64, 64) to (256, 256)
# Resizing ID_MSQ7RV from (64, 64) to (256, 256)
# Resizing ID_TW6515 from (64, 64) to (256, 256)
# 533/715 ━━━━━━━━━━━━━━━━━━━━ 1:40 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6096 - precision_m: 1.2133 - recall_m: 1.1568Resizing ID_C4KIM2 from (64, 64) to (256, 256)
# Resizing ID_23BGX7 from (64, 64) to (256, 256)
# Resizing ID_J9WS4X from (64, 64) to (256, 256)
# Resizing ID_DJHSSB from (64, 64) to (256, 256)
# Resizing ID_8VMMFS from (64, 64) to (256, 256)
# Resizing ID_2XP4DA from (64, 64) to (256, 256)
# Resizing ID_5RMNYH from (64, 64) to (256, 256)
# Resizing ID_4ZT8P4 from (64, 64) to (256, 256)
# 534/715 ━━━━━━━━━━━━━━━━━━━━ 1:40 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6095 - precision_m: 1.2135 - recall_m: 1.1572Resizing ID_DPGA8J from (64, 64) to (256, 256)
# Resizing ID_O7LSKU from (64, 64) to (256, 256)
# Resizing ID_3GMASF from (64, 64) to (256, 256)
# Resizing ID_Z6HB0A from (64, 64) to (256, 256)
# Resizing ID_BWGR20 from (64, 64) to (256, 256)
# Resizing ID_VO7TJE from (64, 64) to (256, 256)
# Resizing ID_ZFST6M from (64, 64) to (256, 256)
# Resizing ID_Z0XFVJ from (64, 64) to (256, 256)
# Resizing ID_BL3QIG from (64, 64) to (256, 256)
# 535/715 ━━━━━━━━━━━━━━━━━━━━ 1:39 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6095 - precision_m: 1.2137 - recall_m: 1.1575Resizing ID_7PLUL9 from (64, 64) to (256, 256)
# Resizing ID_8JA2LT from (64, 64) to (256, 256)
# Resizing ID_AQ23YS from (64, 64) to (256, 256)
# Resizing ID_90UXQV from (64, 64) to (256, 256)
# Resizing ID_RXWQRC from (64, 64) to (256, 256)
# Resizing ID_C91KSV from (64, 64) to (256, 256)
# Resizing ID_AY00AI from (64, 64) to (256, 256)
# 536/715 ━━━━━━━━━━━━━━━━━━━━ 1:39 553ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6094 - precision_m: 1.2139 - recall_m: 1.1579Resizing ID_333Q6N from (64, 64) to (256, 256)
# Resizing ID_CPQBKY from (64, 64) to (256, 256)
# Resizing ID_8UMZ0D from (64, 64) to (256, 256)
# Resizing ID_36980A from (64, 64) to (256, 256)
# Resizing ID_4VGXRJ from (64, 64) to (256, 256)
# Resizing ID_3OP19Z from (64, 64) to (256, 256)
# Resizing ID_A8UJMX from (64, 64) to (256, 256)
# Resizing ID_LCOPBX from (64, 64) to (256, 256)
# 537/715 ━━━━━━━━━━━━━━━━━━━━ 1:38 553ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6094 - precision_m: 1.2141 - recall_m: 1.1582Resizing ID_SC3WAL from (64, 64) to (256, 256)
# Resizing ID_LU6BHF from (64, 64) to (256, 256)
# Resizing ID_TEQC5B from (64, 64) to (256, 256)
# Resizing ID_GX4WRP from (64, 64) to (256, 256)
# Resizing ID_EKYJJJ from (64, 64) to (256, 256)
# Resizing ID_9S8EZI from (64, 64) to (256, 256)
# Resizing ID_P5P0XN from (64, 64) to (256, 256)
# Resizing ID_JIGN7R from (64, 64) to (256, 256)
# 538/715 ━━━━━━━━━━━━━━━━━━━━ 1:37 553ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6093 - precision_m: 1.2143 - recall_m: 1.1586Resizing ID_VUHG1U from (64, 64) to (256, 256)
# Resizing ID_WMNDA4 from (64, 64) to (256, 256)
# Resizing ID_SNI0Y0 from (64, 64) to (256, 256)
# Resizing ID_0XN8K1 from (64, 64) to (256, 256)
# Resizing ID_COVBK4 from (64, 64) to (256, 256)
# Resizing ID_8USBWC from (64, 64) to (256, 256)
# Resizing ID_1D9KS7 from (64, 64) to (256, 256)
# Resizing ID_OCO9LW from (64, 64) to (256, 256)
# 539/715 ━━━━━━━━━━━━━━━━━━━━ 1:37 553ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6093 - precision_m: 1.2145 - recall_m: 1.1589Resizing ID_9HTZKV from (64, 64) to (256, 256)
# Resizing ID_PAB4VN from (64, 64) to (256, 256)
# Resizing ID_7F2OCJ from (64, 64) to (256, 256)
# Resizing ID_ATLVAK from (64, 64) to (256, 256)
# Resizing ID_D1L8GP from (64, 64) to (256, 256)
# Resizing ID_GYSFJZ from (64, 64) to (256, 256)
# Resizing ID_VFLASX from (64, 64) to (256, 256)
# Resizing ID_V1LZYY from (64, 64) to (256, 256)
# 540/715 ━━━━━━━━━━━━━━━━━━━━ 1:36 553ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6092 - precision_m: 1.2146 - recall_m: 1.1593Resizing ID_AI3BBC from (64, 64) to (256, 256)
# Resizing ID_97AQ5G from (64, 64) to (256, 256)
# Resizing ID_VYA537 from (64, 64) to (256, 256)
# Resizing ID_8EJL3G from (64, 64) to (256, 256)
# Resizing ID_5FDJQR from (64, 64) to (256, 256)
# Resizing ID_15V644 from (64, 64) to (256, 256)
# Resizing ID_5FXS8S from (64, 64) to (256, 256)
# Resizing ID_J2E9BT from (64, 64) to (256, 256)
# 541/715 ━━━━━━━━━━━━━━━━━━━━ 1:36 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6092 - precision_m: 1.2148 - recall_m: 1.1596Resizing ID_AUH4C9 from (64, 64) to (256, 256)
# Resizing ID_UAZASL from (64, 64) to (256, 256)
# Resizing ID_ADJV1G from (64, 64) to (256, 256)
# Resizing ID_ZMC3OL from (64, 64) to (256, 256)
# Resizing ID_44R8D2 from (64, 64) to (256, 256)
# Resizing ID_5Z7D97 from (64, 64) to (256, 256)
# Resizing ID_0VSHOR from (64, 64) to (256, 256)
# Resizing ID_2VKKRD from (64, 64) to (256, 256)
# 542/715 ━━━━━━━━━━━━━━━━━━━━ 1:35 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6091 - precision_m: 1.2150 - recall_m: 1.1600Resizing ID_HTPYE1 from (64, 64) to (256, 256)
# Resizing ID_529LRJ from (64, 64) to (256, 256)
# Resizing ID_2RQFX7 from (64, 64) to (256, 256)
# Resizing ID_TH2Z5F from (64, 64) to (256, 256)
# Resizing ID_25DAGA from (64, 64) to (256, 256)
# Resizing ID_9UZ2CZ from (64, 64) to (256, 256)
# Resizing ID_6WIXLU from (64, 64) to (256, 256)
# Resizing ID_E06KB4 from (64, 64) to (256, 256)
# 543/715 ━━━━━━━━━━━━━━━━━━━━ 1:35 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6091 - precision_m: 1.2152 - recall_m: 1.1604Resizing ID_43JTWR from (64, 64) to (256, 256)
# Resizing ID_DTOUIB from (64, 64) to (256, 256)
# Resizing ID_HGDG8B from (64, 64) to (256, 256)
# Resizing ID_5FQ4L3 from (64, 64) to (256, 256)
# Resizing ID_YJLC31 from (64, 64) to (256, 256)
# Resizing ID_DMZT7A from (64, 64) to (256, 256)
# Resizing ID_RKNMQF from (64, 64) to (256, 256)
# Resizing ID_9K4T13 from (64, 64) to (256, 256)
# 544/715 ━━━━━━━━━━━━━━━━━━━━ 1:34 555ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4677 - loss: 0.6090 - precision_m: 1.2154 - recall_m: 1.1607Resizing ID_DA73VA from (64, 64) to (256, 256)
# Resizing ID_Q5E10F from (64, 64) to (256, 256)
# Resizing ID_PVHVY3 from (64, 64) to (256, 256)
# Resizing ID_LGZHC6 from (64, 64) to (256, 256)
# Resizing ID_L3Q1YL from (64, 64) to (256, 256)
# Resizing ID_K59CZY from (64, 64) to (256, 256)
# Resizing ID_NGU29N from (64, 64) to (256, 256)
# Resizing ID_531YUB from (64, 64) to (256, 256)
# 545/715 ━━━━━━━━━━━━━━━━━━━━ 1:34 555ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6090 - precision_m: 1.2156 - recall_m: 1.1611Resizing ID_WDUR6K from (64, 64) to (256, 256)
# Resizing ID_XG9GFL from (64, 64) to (256, 256)
# Resizing ID_KEFDQA from (64, 64) to (256, 256)
# Resizing ID_GGHSL0 from (64, 64) to (256, 256)
# Resizing ID_9VRIV2 from (64, 64) to (256, 256)
# Resizing ID_BPE09Z from (64, 64) to (256, 256)
# Resizing ID_Q3HTFK from (64, 64) to (256, 256)
# Resizing ID_WO2XZW from (64, 64) to (256, 256)
# 546/715 ━━━━━━━━━━━━━━━━━━━━ 1:33 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6089 - precision_m: 1.2158 - recall_m: 1.1614Resizing ID_C8K73S from (64, 64) to (256, 256)
# Resizing ID_5FDUIT from (64, 64) to (256, 256)
# Resizing ID_1Q8GPK from (64, 64) to (256, 256)
# Resizing ID_7KJDJ1 from (64, 64) to (256, 256)
# Resizing ID_1D9Y15 from (64, 64) to (256, 256)
# Resizing ID_JDI4QB from (64, 64) to (256, 256)
# Resizing ID_86KPSU from (64, 64) to (256, 256)
# Resizing ID_6PRLOC from (64, 64) to (256, 256)
# 547/715 ━━━━━━━━━━━━━━━━━━━━ 1:33 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6089 - precision_m: 1.2160 - recall_m: 1.1618Resizing ID_CFJQJ6 from (64, 64) to (256, 256)
# Resizing ID_KADBSQ from (64, 64) to (256, 256)
# Resizing ID_0S9XGK from (64, 64) to (256, 256)
# Resizing ID_KDNPQA from (64, 64) to (256, 256)
# Resizing ID_AQ991A from (64, 64) to (256, 256)
# Resizing ID_Z7P4UR from (64, 64) to (256, 256)
# Resizing ID_G2LQO9 from (64, 64) to (256, 256)
# Resizing ID_X7DHP9 from (64, 64) to (256, 256)
# 548/715 ━━━━━━━━━━━━━━━━━━━━ 1:32 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6088 - precision_m: 1.2161 - recall_m: 1.1621Resizing ID_HNFC7M from (64, 64) to (256, 256)
# Resizing ID_TZXV59 from (64, 64) to (256, 256)
# Resizing ID_TZG015 from (64, 64) to (256, 256)
# Resizing ID_AVFGQG from (64, 64) to (256, 256)
# Resizing ID_UDJJ0U from (64, 64) to (256, 256)
# Resizing ID_O1CU8J from (64, 64) to (256, 256)
# Resizing ID_MMU3MD from (64, 64) to (256, 256)
# Resizing ID_L0H1HK from (64, 64) to (256, 256)
# 549/715 ━━━━━━━━━━━━━━━━━━━━ 1:31 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6088 - precision_m: 1.2163 - recall_m: 1.1625Resizing ID_W2LJ51 from (64, 64) to (256, 256)
# Resizing ID_JE7ZPI from (64, 64) to (256, 256)
# Resizing ID_D9584P from (64, 64) to (256, 256)
# Resizing ID_CNDSI7 from (64, 64) to (256, 256)
# Resizing ID_X9KP3C from (64, 64) to (256, 256)
# Resizing ID_1RBF6V from (64, 64) to (256, 256)
# Resizing ID_VLJHLZ from (64, 64) to (256, 256)
# Resizing ID_AC3P0A from (64, 64) to (256, 256)
# 550/715 ━━━━━━━━━━━━━━━━━━━━ 1:31 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6087 - precision_m: 1.2165 - recall_m: 1.1628Resizing ID_4CQ49Q from (64, 64) to (256, 256)
# Resizing ID_YUTUBJ from (64, 64) to (256, 256)
# Resizing ID_CV8VK8 from (64, 64) to (256, 256)
# Resizing ID_9LG374 from (64, 64) to (256, 256)
# Resizing ID_42BL5M from (64, 64) to (256, 256)
# Resizing ID_J5SGPJ from (64, 64) to (256, 256)
# Resizing ID_OWWEG4 from (64, 64) to (256, 256)
# Resizing ID_LJ41PH from (64, 64) to (256, 256)
# 551/715 ━━━━━━━━━━━━━━━━━━━━ 1:30 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6087 - precision_m: 1.2167 - recall_m: 1.1632Resizing ID_I5D5C9 from (64, 64) to (256, 256)
# Resizing ID_IA0F92 from (64, 64) to (256, 256)
# Resizing ID_VKFCFL from (64, 64) to (256, 256)
# Resizing ID_UL0S2J from (64, 64) to (256, 256)
# Resizing ID_6PW2LY from (64, 64) to (256, 256)
# Resizing ID_ZKLA60 from (64, 64) to (256, 256)
# Resizing ID_2JO6IX from (64, 64) to (256, 256)
# Resizing ID_VRJ5WU from (64, 64) to (256, 256)
# 552/715 ━━━━━━━━━━━━━━━━━━━━ 1:30 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6086 - precision_m: 1.2169 - recall_m: 1.1636Resizing ID_DFIBY7 from (64, 64) to (256, 256)
# Resizing ID_7FOLWE from (64, 64) to (256, 256)
# Resizing ID_MGDYEE from (64, 64) to (256, 256)
# Resizing ID_TL191V from (64, 64) to (256, 256)
# Resizing ID_GF0DPU from (64, 64) to (256, 256)
# Resizing ID_FFEZSR from (64, 64) to (256, 256)
# Resizing ID_1N7KC1 from (64, 64) to (256, 256)
# Resizing ID_WT6Y3M from (64, 64) to (256, 256)
# 553/715 ━━━━━━━━━━━━━━━━━━━━ 1:29 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6086 - precision_m: 1.2171 - recall_m: 1.1639Resizing ID_01Q4UV from (64, 64) to (256, 256)
# Resizing ID_ZO22GP from (64, 64) to (256, 256)
# Resizing ID_8ZLP3O from (64, 64) to (256, 256)
# Resizing ID_JYMHBL from (64, 64) to (256, 256)
# Resizing ID_BF4VV7 from (64, 64) to (256, 256)
# Resizing ID_MT386H from (64, 64) to (256, 256)
# Resizing ID_62X7IN from (64, 64) to (256, 256)
# Resizing ID_W16ATZ from (64, 64) to (256, 256)
# 554/715 ━━━━━━━━━━━━━━━━━━━━ 1:29 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6085 - precision_m: 1.2173 - recall_m: 1.1643Resizing ID_1TJTP7 from (64, 64) to (256, 256)
# Resizing ID_EVS6QM from (64, 64) to (256, 256)
# Resizing ID_PTKZ48 from (64, 64) to (256, 256)
# Resizing ID_F1OXNQ from (64, 64) to (256, 256)
# Resizing ID_IL3YLV from (64, 64) to (256, 256)
# Resizing ID_DOS4AO from (64, 64) to (256, 256)
# Resizing ID_HFVLKB from (64, 64) to (256, 256)
# Resizing ID_3JAYTC from (64, 64) to (256, 256)
# 555/715 ━━━━━━━━━━━━━━━━━━━━ 1:28 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6085 - precision_m: 1.2175 - recall_m: 1.1646Resizing ID_KU5OII from (64, 64) to (256, 256)
# Resizing ID_E3KWY8 from (64, 64) to (256, 256)
# Resizing ID_QZ54I0 from (64, 64) to (256, 256)
# Resizing ID_EFI1X1 from (64, 64) to (256, 256)
# Resizing ID_O5JPU6 from (64, 64) to (256, 256)
# Resizing ID_2T0DRQ from (64, 64) to (256, 256)
# Resizing ID_0RINYQ from (64, 64) to (256, 256)
# Resizing ID_HLLUPF from (64, 64) to (256, 256)
# 556/715 ━━━━━━━━━━━━━━━━━━━━ 1:28 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6084 - precision_m: 1.2177 - recall_m: 1.1650Resizing ID_WEIL0D from (64, 64) to (256, 256)
# Resizing ID_WULDGQ from (64, 64) to (256, 256)
# Resizing ID_HR1IGC from (64, 64) to (256, 256)
# Resizing ID_WA56HA from (64, 64) to (256, 256)
# Resizing ID_BELNVG from (64, 64) to (256, 256)
# Resizing ID_VS15WJ from (64, 64) to (256, 256)
# Resizing ID_NQBBT0 from (64, 64) to (256, 256)
# Resizing ID_T4K580 from (64, 64) to (256, 256)
# 557/715 ━━━━━━━━━━━━━━━━━━━━ 1:27 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6084 - precision_m: 1.2179 - recall_m: 1.1653Resizing ID_Y356MZ from (64, 64) to (256, 256)
# Resizing ID_MG038K from (64, 64) to (256, 256)
# Resizing ID_20HG96 from (64, 64) to (256, 256)
# Resizing ID_B8L6VM from (64, 64) to (256, 256)
# Resizing ID_CENS5G from (64, 64) to (256, 256)
# Resizing ID_85B51K from (64, 64) to (256, 256)
# Resizing ID_HH0O15 from (64, 64) to (256, 256)
# Resizing ID_10BSXQ from (64, 64) to (256, 256)
# 558/715 ━━━━━━━━━━━━━━━━━━━━ 1:26 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6083 - precision_m: 1.2181 - recall_m: 1.1656Resizing ID_E0OZAM from (64, 64) to (256, 256)
# Resizing ID_NMX20U from (64, 64) to (256, 256)
# Resizing ID_876R9M from (64, 64) to (256, 256)
# Resizing ID_EH28TI from (64, 64) to (256, 256)
# Resizing ID_E859G9 from (64, 64) to (256, 256)
# Resizing ID_1UW062 from (64, 64) to (256, 256)
# Resizing ID_4K5Q8P from (64, 64) to (256, 256)
# Resizing ID_OQJ1ZZ from (64, 64) to (256, 256)
# 559/715 ━━━━━━━━━━━━━━━━━━━━ 1:26 554ms/step - accuracy: 0.7204 - balanced_f1_score: 0.4678 - loss: 0.6083 - precision_m: 1.2182 - recall_m: 1.1660Resizing ID_GYWZ84 from (64, 64) to (256, 256)
# Resizing ID_GV83D5 from (64, 64) to (256, 256)
# Resizing ID_L9RJOC from (64, 64) to (256, 256)
# Resizing ID_W2XCO8 from (64, 64) to (256, 256)
# Resizing ID_J9AVRY from (64, 64) to (256, 256)
# Resizing ID_QP2GKZ from (64, 64) to (256, 256)
# Resizing ID_4IWL6V from (64, 64) to (256, 256)
# Resizing ID_KGCQ2N from (64, 64) to (256, 256)
# 560/715 ━━━━━━━━━━━━━━━━━━━━ 1:25 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4678 - loss: 0.6082 - precision_m: 1.2184 - recall_m: 1.1663Resizing ID_B18SQN from (64, 64) to (256, 256)
# Resizing ID_MHKD6D from (64, 64) to (256, 256)
# Resizing ID_U5NU3O from (64, 64) to (256, 256)
# Resizing ID_4TVMLQ from (64, 64) to (256, 256)
# Resizing ID_8BN7XT from (64, 64) to (256, 256)
# Resizing ID_IVHZY9 from (64, 64) to (256, 256)
# Resizing ID_74TYSD from (64, 64) to (256, 256)
# Resizing ID_HBAE7Z from (64, 64) to (256, 256)
# 561/715 ━━━━━━━━━━━━━━━━━━━━ 1:25 553ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4678 - loss: 0.6082 - precision_m: 1.2186 - recall_m: 1.1667Resizing ID_LKPBOG from (64, 64) to (256, 256)
# Resizing ID_B2VEUL from (64, 64) to (256, 256)
# Resizing ID_RS2LY4 from (64, 64) to (256, 256)
# Resizing ID_2U0ARI from (64, 64) to (256, 256)
# Resizing ID_E3VN9Z from (64, 64) to (256, 256)
# Resizing ID_QQHMQ1 from (64, 64) to (256, 256)
# Resizing ID_E1W6FD from (64, 64) to (256, 256)
# Resizing ID_868AH2 from (64, 64) to (256, 256)
# 562/715 ━━━━━━━━━━━━━━━━━━━━ 1:24 553ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4678 - loss: 0.6082 - precision_m: 1.2188 - recall_m: 1.1670Resizing ID_QOZPGM from (64, 64) to (256, 256)
# Resizing ID_FKMNCO from (64, 64) to (256, 256)
# Resizing ID_9XI3GQ from (64, 64) to (256, 256)
# Resizing ID_5ENLXR from (64, 64) to (256, 256)
# Resizing ID_VNFVG0 from (64, 64) to (256, 256)
# Resizing ID_E528XV from (64, 64) to (256, 256)
# Resizing ID_ZASAPN from (64, 64) to (256, 256)
# Resizing ID_76Z6PR from (64, 64) to (256, 256)
# 563/715 ━━━━━━━━━━━━━━━━━━━━ 1:24 553ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6081 - precision_m: 1.2190 - recall_m: 1.1673Resizing ID_2XWHWF from (64, 64) to (256, 256)
# Resizing ID_TSMIJ2 from (64, 64) to (256, 256)
# Resizing ID_H2D9HP from (64, 64) to (256, 256)
# Resizing ID_KBLUY9 from (64, 64) to (256, 256)
# Resizing ID_GQZ8N8 from (64, 64) to (256, 256)
# Resizing ID_59PHPU from (64, 64) to (256, 256)
# Resizing ID_TG1FLT from (64, 64) to (256, 256)
# Resizing ID_GB9RDA from (64, 64) to (256, 256)
# 564/715 ━━━━━━━━━━━━━━━━━━━━ 1:23 553ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6081 - precision_m: 1.2192 - recall_m: 1.1677Resizing ID_8Y3N7U from (64, 64) to (256, 256)
# Resizing ID_IAJDBD from (64, 64) to (256, 256)
# Resizing ID_IZ53V5 from (64, 64) to (256, 256)
# Resizing ID_GJHY4V from (64, 64) to (256, 256)
# Resizing ID_ADL2VI from (64, 64) to (256, 256)
# Resizing ID_1KRUK3 from (64, 64) to (256, 256)
# Resizing ID_ALMEAK from (64, 64) to (256, 256)
# Resizing ID_PXHNYL from (64, 64) to (256, 256)
# 565/715 ━━━━━━━━━━━━━━━━━━━━ 1:23 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6080 - precision_m: 1.2193 - recall_m: 1.1680Resizing ID_H9DAN3 from (64, 64) to (256, 256)
# Resizing ID_7E4I92 from (64, 64) to (256, 256)
# Resizing ID_69G7LP from (64, 64) to (256, 256)
# Resizing ID_72DFH4 from (64, 64) to (256, 256)
# Resizing ID_FVU40R from (64, 64) to (256, 256)
# Resizing ID_0M4X08 from (64, 64) to (256, 256)
# Resizing ID_CLNGMR from (64, 64) to (256, 256)
# Resizing ID_SI0WR8 from (64, 64) to (256, 256)
# 566/715 ━━━━━━━━━━━━━━━━━━━━ 1:22 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6080 - precision_m: 1.2195 - recall_m: 1.1683Resizing ID_YMB5RP from (64, 64) to (256, 256)
# Resizing ID_QHRE1O from (64, 64) to (256, 256)
# Resizing ID_6SIOZ3 from (64, 64) to (256, 256)
# Resizing ID_U9QN2D from (64, 64) to (256, 256)
# Resizing ID_0ZXWH1 from (64, 64) to (256, 256)
# Resizing ID_GH71V2 from (64, 64) to (256, 256)
# Resizing ID_FN1JKB from (64, 64) to (256, 256)
# Resizing ID_L9L53P from (64, 64) to (256, 256)
# 567/715 ━━━━━━━━━━━━━━━━━━━━ 1:21 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6079 - precision_m: 1.2197 - recall_m: 1.1686Resizing ID_TUBMBU from (64, 64) to (256, 256)
# Resizing ID_VRIAE1 from (64, 64) to (256, 256)
# Resizing ID_NV2HR8 from (64, 64) to (256, 256)
# Resizing ID_Y7FIFG from (64, 64) to (256, 256)
# Resizing ID_CHIXM7 from (64, 64) to (256, 256)
# Resizing ID_0DAGAH from (64, 64) to (256, 256)
# Resizing ID_RE5U2F from (64, 64) to (256, 256)
# Resizing ID_BK5OSP from (64, 64) to (256, 256)
# 568/715 ━━━━━━━━━━━━━━━━━━━━ 1:21 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6079 - precision_m: 1.2198 - recall_m: 1.1689Resizing ID_PARMPZ from (64, 64) to (256, 256)
# Resizing ID_E8DZG5 from (64, 64) to (256, 256)
# Resizing ID_W8TGCY from (64, 64) to (256, 256)
# Resizing ID_WJK1BQ from (64, 64) to (256, 256)
# Resizing ID_HJ0C53 from (64, 64) to (256, 256)
# Resizing ID_N3G726 from (64, 64) to (256, 256)
# Resizing ID_84LOOT from (64, 64) to (256, 256)
# Resizing ID_UH37LA from (64, 64) to (256, 256)
# 569/715 ━━━━━━━━━━━━━━━━━━━━ 1:20 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6078 - precision_m: 1.2200 - recall_m: 1.1693Resizing ID_4QYE2H from (64, 64) to (256, 256)
# Resizing ID_9B0HGU from (64, 64) to (256, 256)
# Resizing ID_1V8RIU from (64, 64) to (256, 256)
# Resizing ID_HRWVP1 from (64, 64) to (256, 256)
# Resizing ID_4NHZKI from (64, 64) to (256, 256)
# Resizing ID_0JHDUB from (64, 64) to (256, 256)
# Resizing ID_3E2W8O from (64, 64) to (256, 256)
# Resizing ID_NS9CET from (64, 64) to (256, 256)
# 570/715 ━━━━━━━━━━━━━━━━━━━━ 1:20 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6078 - precision_m: 1.2202 - recall_m: 1.1696Resizing ID_TB0EIN from (64, 64) to (256, 256)
# Resizing ID_ZNCW42 from (64, 64) to (256, 256)
# Resizing ID_7AAGXC from (64, 64) to (256, 256)
# Resizing ID_M889ZE from (64, 64) to (256, 256)
# Resizing ID_IRA2O4 from (64, 64) to (256, 256)
# Resizing ID_WWMY2M from (64, 64) to (256, 256)
# Resizing ID_NI5JVQ from (64, 64) to (256, 256)
# Resizing ID_340D5C from (64, 64) to (256, 256)
# 571/715 ━━━━━━━━━━━━━━━━━━━━ 1:19 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6077 - precision_m: 1.2204 - recall_m: 1.1699Resizing ID_AVAAJP from (64, 64) to (256, 256)
# Resizing ID_47LY3Y from (64, 64) to (256, 256)
# Resizing ID_SWRJII from (64, 64) to (256, 256)
# Resizing ID_ORGFW7 from (64, 64) to (256, 256)
# Resizing ID_2IC5XL from (64, 64) to (256, 256)
# Resizing ID_ONLD6X from (64, 64) to (256, 256)
# Resizing ID_O8LQ6T from (64, 64) to (256, 256)
# Resizing ID_QTPAXI from (64, 64) to (256, 256)
# 572/715 ━━━━━━━━━━━━━━━━━━━━ 1:19 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6077 - precision_m: 1.2206 - recall_m: 1.1702Resizing ID_6BGRYU from (64, 64) to (256, 256)
# Resizing ID_LM5RA9 from (64, 64) to (256, 256)
# Resizing ID_LA10SU from (64, 64) to (256, 256)
# Resizing ID_CMM2LP from (64, 64) to (256, 256)
# Resizing ID_MX41BJ from (64, 64) to (256, 256)
# Resizing ID_B29MKB from (64, 64) to (256, 256)
# Resizing ID_O4D8IK from (64, 64) to (256, 256)
# Resizing ID_PRRSOG from (64, 64) to (256, 256)
# 573/715 ━━━━━━━━━━━━━━━━━━━━ 1:18 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6076 - precision_m: 1.2207 - recall_m: 1.1705Resizing ID_M9U9XF from (64, 64) to (256, 256)
# Resizing ID_7T1L3N from (64, 64) to (256, 256)
# Resizing ID_B0FDJS from (64, 64) to (256, 256)
# Resizing ID_XWPXXL from (64, 64) to (256, 256)
# Resizing ID_JWJI3S from (64, 64) to (256, 256)
# Resizing ID_M3AYHJ from (64, 64) to (256, 256)
# Resizing ID_SCRTP3 from (64, 64) to (256, 256)
# Resizing ID_BIY29I from (64, 64) to (256, 256)
# 574/715 ━━━━━━━━━━━━━━━━━━━━ 1:18 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6076 - precision_m: 1.2209 - recall_m: 1.1709Resizing ID_MOOJIE from (64, 64) to (256, 256)
# Resizing ID_1Z0NV8 from (64, 64) to (256, 256)
# Resizing ID_UQ8U69 from (64, 64) to (256, 256)
# Resizing ID_RSUKO3 from (64, 64) to (256, 256)
# Resizing ID_K3R5ZH from (64, 64) to (256, 256)
# Resizing ID_57DIJ4 from (64, 64) to (256, 256)
# Resizing ID_L5CPXT from (64, 64) to (256, 256)
# Resizing ID_98IMFV from (64, 64) to (256, 256)
# 575/715 ━━━━━━━━━━━━━━━━━━━━ 1:17 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6075 - precision_m: 1.2211 - recall_m: 1.1712Resizing ID_JFNWDO from (64, 64) to (256, 256)
# Resizing ID_43224D from (64, 64) to (256, 256)
# Resizing ID_O6UUZ9 from (64, 64) to (256, 256)
# Resizing ID_KGIYFV from (64, 64) to (256, 256)
# Resizing ID_HO4UYF from (64, 64) to (256, 256)
# Resizing ID_O7PIJY from (64, 64) to (256, 256)
# Resizing ID_FGNPGN from (64, 64) to (256, 256)
# Resizing ID_N888F6 from (64, 64) to (256, 256)
# 576/715 ━━━━━━━━━━━━━━━━━━━━ 1:16 554ms/step - accuracy: 0.7205 - balanced_f1_score: 0.4679 - loss: 0.6075 - precision_m: 1.2213 - recall_m: 1.1715Resizing ID_HMSG74 from (64, 64) to (256, 256)
# Resizing ID_EZFGBX from (64, 64) to (256, 256)
# Resizing ID_M8ZHY6 from (64, 64) to (256, 256)
# Resizing ID_OTK26D from (64, 64) to (256, 256)
# Resizing ID_AZLQG7 from (64, 64) to (256, 256)
# Resizing ID_Q73011 from (64, 64) to (256, 256)
# Resizing ID_Q54LHJ from (64, 64) to (256, 256)
# Resizing ID_TRJ9C3 from (64, 64) to (256, 256)
# 577/715 ━━━━━━━━━━━━━━━━━━━━ 1:16 554ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4679 - loss: 0.6074 - precision_m: 1.2214 - recall_m: 1.1718Resizing ID_RSF89V from (64, 64) to (256, 256)
# Resizing ID_9VVUNH from (64, 64) to (256, 256)
# Resizing ID_ZVNIOP from (64, 64) to (256, 256)
# Resizing ID_9OW8Z8 from (64, 64) to (256, 256)
# Resizing ID_CQNEA2 from (64, 64) to (256, 256)
# Resizing ID_IQ1CKK from (64, 64) to (256, 256)
# Resizing ID_EW0Y8H from (64, 64) to (256, 256)
# Resizing ID_3BPODL from (64, 64) to (256, 256)
# 578/715 ━━━━━━━━━━━━━━━━━━━━ 1:15 554ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4679 - loss: 0.6074 - precision_m: 1.2216 - recall_m: 1.1721Resizing ID_D3IKZE from (64, 64) to (256, 256)
# Resizing ID_AK3ICU from (64, 64) to (256, 256)
# Resizing ID_W73AFC from (64, 64) to (256, 256)
# Resizing ID_HF19MV from (64, 64) to (256, 256)
# Resizing ID_EJ9P1J from (64, 64) to (256, 256)
# Resizing ID_8W9IRK from (64, 64) to (256, 256)
# Resizing ID_CWAQRQ from (64, 64) to (256, 256)
# Resizing ID_OUEWP2 from (64, 64) to (256, 256)
# 579/715 ━━━━━━━━━━━━━━━━━━━━ 1:15 554ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4679 - loss: 0.6073 - precision_m: 1.2218 - recall_m: 1.1724Resizing ID_QQHKD5 from (64, 64) to (256, 256)
# Resizing ID_JGIF2L from (64, 64) to (256, 256)
# Resizing ID_V2H7ML from (64, 64) to (256, 256)
# Resizing ID_5X6X94 from (64, 64) to (256, 256)
# Resizing ID_YC59K3 from (64, 64) to (256, 256)
# Resizing ID_G1CYS5 from (64, 64) to (256, 256)
# Resizing ID_PDB3GJ from (64, 64) to (256, 256)
# Resizing ID_HBQ7OR from (64, 64) to (256, 256)
# 580/715 ━━━━━━━━━━━━━━━━━━━━ 1:14 554ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4679 - loss: 0.6073 - precision_m: 1.2220 - recall_m: 1.1727Resizing ID_BOZZOT from (64, 64) to (256, 256)
# Resizing ID_BF9W67 from (64, 64) to (256, 256)
# Resizing ID_A0256D from (64, 64) to (256, 256)
# Resizing ID_SZF7CG from (64, 64) to (256, 256)
# Resizing ID_PI1Z8W from (64, 64) to (256, 256)
# Resizing ID_0ZCZKC from (64, 64) to (256, 256)
# Resizing ID_Y81ZRS from (64, 64) to (256, 256)
# Resizing ID_SXJ58E from (64, 64) to (256, 256)
# 581/715 ━━━━━━━━━━━━━━━━━━━━ 1:14 554ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4679 - loss: 0.6072 - precision_m: 1.2222 - recall_m: 1.1730Resizing ID_ZANSBY from (64, 64) to (256, 256)
# Resizing ID_AZS6NA from (64, 64) to (256, 256)
# Resizing ID_RQPBS0 from (64, 64) to (256, 256)
# Resizing ID_WTCWIO from (64, 64) to (256, 256)
# Resizing ID_XZZCZL from (64, 64) to (256, 256)
# Resizing ID_I3YTNM from (64, 64) to (256, 256)
# Resizing ID_924778 from (64, 64) to (256, 256)
# Resizing ID_CXP0GD from (64, 64) to (256, 256)
# 582/715 ━━━━━━━━━━━━━━━━━━━━ 1:13 554ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4680 - loss: 0.6072 - precision_m: 1.2223 - recall_m: 1.1733Resizing ID_RPMKEY from (64, 64) to (256, 256)
# Resizing ID_AYWLNG from (64, 64) to (256, 256)
# Resizing ID_G9XAC4 from (64, 64) to (256, 256)
# Resizing ID_AD2B3W from (64, 64) to (256, 256)
# Resizing ID_TTLL9P from (64, 64) to (256, 256)
# Resizing ID_1YNVWC from (64, 64) to (256, 256)
# Resizing ID_RAUE1N from (64, 64) to (256, 256)
# Resizing ID_H2M5DT from (64, 64) to (256, 256)
# 583/715 ━━━━━━━━━━━━━━━━━━━━ 1:13 554ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4680 - loss: 0.6071 - precision_m: 1.2225 - recall_m: 1.1736Resizing ID_XD0LVF from (64, 64) to (256, 256)
# Resizing ID_HBURF6 from (64, 64) to (256, 256)
# Resizing ID_W4N7EN from (64, 64) to (256, 256)
# Resizing ID_P25213 from (64, 64) to (256, 256)
# Resizing ID_ZA51AK from (64, 64) to (256, 256)
# Resizing ID_EEARO5 from (64, 64) to (256, 256)
# Resizing ID_LL0KX4 from (64, 64) to (256, 256)
# Resizing ID_D3I34N from (64, 64) to (256, 256)
# 584/715 ━━━━━━━━━━━━━━━━━━━━ 1:12 554ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4680 - loss: 0.6071 - precision_m: 1.2227 - recall_m: 1.1739Resizing ID_9W4SSJ from (64, 64) to (256, 256)
# Resizing ID_5R11N4 from (64, 64) to (256, 256)
# Resizing ID_8UNBVH from (64, 64) to (256, 256)
# Resizing ID_PUU5OF from (64, 64) to (256, 256)
# Resizing ID_TP3UER from (64, 64) to (256, 256)
# Resizing ID_CGMSAY from (64, 64) to (256, 256)
# Resizing ID_CEX4NM from (64, 64) to (256, 256)
# Resizing ID_0JPHH2 from (64, 64) to (256, 256)
# 585/715 ━━━━━━━━━━━━━━━━━━━━ 1:11 553ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4680 - loss: 0.6070 - precision_m: 1.2229 - recall_m: 1.1743Resizing ID_ZNW143 from (64, 64) to (256, 256)
# Resizing ID_Y2CASO from (64, 64) to (256, 256)
# Resizing ID_3JWWED from (64, 64) to (256, 256)
# Resizing ID_86QUYE from (64, 64) to (256, 256)
# Resizing ID_Y7W4YW from (64, 64) to (256, 256)
# Resizing ID_IVJJ0E from (64, 64) to (256, 256)
# Resizing ID_DRLITV from (64, 64) to (256, 256)
# Resizing ID_LS7LDO from (64, 64) to (256, 256)
# 586/715 ━━━━━━━━━━━━━━━━━━━━ 1:11 553ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4680 - loss: 0.6070 - precision_m: 1.2230 - recall_m: 1.1746Resizing ID_878PE1 from (64, 64) to (256, 256)
# Resizing ID_H4J1P6 from (64, 64) to (256, 256)
# Resizing ID_2Z7V5N from (64, 64) to (256, 256)
# Resizing ID_FPMAZC from (64, 64) to (256, 256)
# Resizing ID_7EME3B from (64, 64) to (256, 256)
# Resizing ID_G3I1ZB from (64, 64) to (256, 256)
# Resizing ID_HU8D3I from (64, 64) to (256, 256)
# Resizing ID_PEWU4B from (64, 64) to (256, 256)
# 587/715 ━━━━━━━━━━━━━━━━━━━━ 1:10 553ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4680 - loss: 0.6069 - precision_m: 1.2232 - recall_m: 1.1749Resizing ID_B83JLY from (64, 64) to (256, 256)
# Resizing ID_7QNM7M from (64, 64) to (256, 256)
# Resizing ID_O2UKST from (64, 64) to (256, 256)
# Resizing ID_80J01G from (64, 64) to (256, 256)
# Resizing ID_96T6WB from (64, 64) to (256, 256)
# Resizing ID_TMWBAH from (64, 64) to (256, 256)
# Resizing ID_6ZGDGB from (64, 64) to (256, 256)
# Resizing ID_WOXBJP from (64, 64) to (256, 256)
# 588/715 ━━━━━━━━━━━━━━━━━━━━ 1:10 553ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4680 - loss: 0.6069 - precision_m: 1.2234 - recall_m: 1.1752Resizing ID_MH9SWL from (64, 64) to (256, 256)
# Resizing ID_WSXTUG from (64, 64) to (256, 256)
# Resizing ID_0I878M from (64, 64) to (256, 256)
# Resizing ID_ISA2T9 from (64, 64) to (256, 256)
# Resizing ID_DS5AI1 from (64, 64) to (256, 256)
# Resizing ID_EZXSB1 from (64, 64) to (256, 256)
# Resizing ID_3KMGQS from (64, 64) to (256, 256)
# Resizing ID_G7AK2S from (64, 64) to (256, 256)
# 589/715 ━━━━━━━━━━━━━━━━━━━━ 1:09 554ms/step - accuracy: 0.7206 - balanced_f1_score: 0.4680 - loss: 0.6068 - precision_m: 1.2235 - recall_m: 1.1755Resizing ID_JRC6XE from (64, 64) to (256, 256)
# Resizing ID_UKG7VR from (64, 64) to (256, 256)
# Resizing ID_CM4LF6 from (64, 64) to (256, 256)
# Resizing ID_A9LCCS from (64, 64) to (256, 256)
# Resizing ID_U2BZK6 from (64, 64) to (256, 256)
# Resizing ID_ONXZG2 from (64, 64) to (256, 256)
# Resizing ID_QJPG8O from (64, 64) to (256, 256)
# Resizing ID_5QWH35 from (64, 64) to (256, 256)
# 590/715 ━━━━━━━━━━━━━━━━━━━━ 1:09 554ms/step - accuracy: 0.7207 - balanced_f1_score: 0.4680 - loss: 0.6068 - precision_m: 1.2237 - recall_m: 1.1758Resizing ID_FC5SRS from (64, 64) to (256, 256)
# Resizing ID_LADTN4 from (64, 64) to (256, 256)
# Resizing ID_CVODQP from (64, 64) to (256, 256)
# Resizing ID_QUDEN4 from (64, 64) to (256, 256)
# Resizing ID_03VUYW from (64, 64) to (256, 256)
# Resizing ID_NIO31X from (64, 64) to (256, 256)
# Resizing ID_NZT6H9 from (64, 64) to (256, 256)
# Resizing ID_QBJ5ME from (64, 64) to (256, 256)
# 591/715 ━━━━━━━━━━━━━━━━━━━━ 1:08 554ms/step - accuracy: 0.7207 - balanced_f1_score: 0.4680 - loss: 0.6067 - precision_m: 1.2239 - recall_m: 1.1761Resizing ID_FS77S3 from (64, 64) to (256, 256)
# Resizing ID_SK6GCY from (64, 64) to (256, 256)
# Resizing ID_H9XBJY from (64, 64) to (256, 256)
# ...
# 210/715 ━━━━━━━━━━━━━━━━━━━━ 4:36 548ms/step - accuracy: 0.7509 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_5SH075 from (64, 64) to (256, 256)
# Resizing ID_WE3P0S from (64, 64) to (256, 256)
# Resizing ID_RSUKO3 from (64, 64) to (256, 256)
# Resizing ID_UFLTU4 from (64, 64) to (256, 256)
# Resizing ID_GM9WH5 from (64, 64) to (256, 256)
# Resizing ID_2VKKRD from (64, 64) to (256, 256)
# Resizing ID_5XNU0Q from (64, 64) to (256, 256)
# Resizing ID_MDRVGV from (64, 64) to (256, 256)
# 211/715 ━━━━━━━━━━━━━━━━━━━━ 4:36 549ms/step - accuracy: 0.7509 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_0DB2LQ from (64, 64) to (256, 256)
# Resizing ID_2IOV5S from (64, 64) to (256, 256)
# Resizing ID_GYSFJZ from (64, 64) to (256, 256)
# Resizing ID_HR1IGC from (64, 64) to (256, 256)
# Resizing ID_2FN37K from (64, 64) to (256, 256)
# Resizing ID_Y8ZIP5 from (64, 64) to (256, 256)
# Resizing ID_X9DURP from (64, 64) to (256, 256)
# Resizing ID_VT615K from (64, 64) to (256, 256)
# 212/715 ━━━━━━━━━━━━━━━━━━━━ 4:36 550ms/step - accuracy: 0.7509 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_5L5NRI from (64, 64) to (256, 256)
# Resizing ID_XXYQ2F from (64, 64) to (256, 256)
# Resizing ID_JAELJ6 from (64, 64) to (256, 256)
# Resizing ID_23BGX7 from (64, 64) to (256, 256)
# Resizing ID_MGJC6K from (64, 64) to (256, 256)
# Resizing ID_F44ZLX from (64, 64) to (256, 256)
# Resizing ID_TN4ISR from (64, 64) to (256, 256)
# Resizing ID_Q4GKLG from (64, 64) to (256, 256)
# 213/715 ━━━━━━━━━━━━━━━━━━━━ 4:36 551ms/step - accuracy: 0.7509 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_5SB842 from (64, 64) to (256, 256)
# Resizing ID_PQTTRN from (64, 64) to (256, 256)
# Resizing ID_N6CC0U from (64, 64) to (256, 256)
# Resizing ID_KDQVY5 from (64, 64) to (256, 256)
# Resizing ID_15DFT2 from (64, 64) to (256, 256)
# Resizing ID_AWL519 from (64, 64) to (256, 256)
# Resizing ID_DBK0ZI from (64, 64) to (256, 256)
# Resizing ID_YW2RG0 from (64, 64) to (256, 256)
# 214/715 ━━━━━━━━━━━━━━━━━━━━ 4:36 551ms/step - accuracy: 0.7509 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_3OFS9I from (64, 64) to (256, 256)
# Resizing ID_D4O909 from (64, 64) to (256, 256)
# Resizing ID_M6D6F0 from (64, 64) to (256, 256)
# Resizing ID_1BLEB8 from (64, 64) to (256, 256)
# Resizing ID_27V7I4 from (64, 64) to (256, 256)
# Resizing ID_BF4VV7 from (64, 64) to (256, 256)
# Resizing ID_JELPG0 from (64, 64) to (256, 256)
# Resizing ID_PFR4NY from (64, 64) to (256, 256)
# 215/715 ━━━━━━━━━━━━━━━━━━━━ 4:35 551ms/step - accuracy: 0.7509 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_WKSILG from (64, 64) to (256, 256)
# Resizing ID_CGMSAY from (64, 64) to (256, 256)
# Resizing ID_ZPY56E from (64, 64) to (256, 256)
# Resizing ID_FWJ706 from (64, 64) to (256, 256)
# Resizing ID_NPL78Q from (64, 64) to (256, 256)
# Resizing ID_BMTPUY from (64, 64) to (256, 256)
# Resizing ID_7DPYC6 from (64, 64) to (256, 256)
# Resizing ID_KPTJCC from (64, 64) to (256, 256)
# 216/715 ━━━━━━━━━━━━━━━━━━━━ 4:34 551ms/step - accuracy: 0.7509 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_U6YORC from (64, 64) to (256, 256)
# Resizing ID_LI0QI6 from (64, 64) to (256, 256)
# Resizing ID_RM5NYY from (64, 64) to (256, 256)
# Resizing ID_R8QIX8 from (64, 64) to (256, 256)
# Resizing ID_F6SKL3 from (64, 64) to (256, 256)
# Resizing ID_WA9PMS from (64, 64) to (256, 256)
# Resizing ID_7EH7SK from (64, 64) to (256, 256)
# Resizing ID_04G1QT from (64, 64) to (256, 256)
# 217/715 ━━━━━━━━━━━━━━━━━━━━ 4:34 550ms/step - accuracy: 0.7510 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_RLXTUU from (64, 64) to (256, 256)
# Resizing ID_6WIXLU from (64, 64) to (256, 256)
# Resizing ID_360ZU3 from (64, 64) to (256, 256)
# Resizing ID_NRY242 from (64, 64) to (256, 256)
# Resizing ID_6DGLH9 from (64, 64) to (256, 256)
# Resizing ID_4C94N6 from (64, 64) to (256, 256)
# Resizing ID_NQ3HVO from (64, 64) to (256, 256)
# Resizing ID_WXOLJB from (64, 64) to (256, 256)
# 218/715 ━━━━━━━━━━━━━━━━━━━━ 4:33 550ms/step - accuracy: 0.7510 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_4X3EPB from (64, 64) to (256, 256)
# Resizing ID_NTLMH5 from (64, 64) to (256, 256)
# Resizing ID_0U95BH from (64, 64) to (256, 256)
# Resizing ID_GV66RY from (64, 64) to (256, 256)
# Resizing ID_Z3YQSV from (64, 64) to (256, 256)
# Resizing ID_JV9QE3 from (64, 64) to (256, 256)
# Resizing ID_KLIV4M from (64, 64) to (256, 256)
# Resizing ID_HRQUCN from (64, 64) to (256, 256)
# 219/715 ━━━━━━━━━━━━━━━━━━━━ 4:32 550ms/step - accuracy: 0.7510 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_HOKM18 from (64, 64) to (256, 256)
# Resizing ID_V49IKZ from (64, 64) to (256, 256)
# Resizing ID_JM0CYN from (64, 64) to (256, 256)
# Resizing ID_6F6GQI from (64, 64) to (256, 256)
# Resizing ID_LRMRQV from (64, 64) to (256, 256)
# Resizing ID_SHUIT3 from (64, 64) to (256, 256)
# Resizing ID_82MFWK from (64, 64) to (256, 256)
# Resizing ID_5AJAUF from (64, 64) to (256, 256)
# 220/715 ━━━━━━━━━━━━━━━━━━━━ 4:32 550ms/step - accuracy: 0.7510 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_6B6FRU from (64, 64) to (256, 256)
# Resizing ID_4N9JBV from (64, 64) to (256, 256)
# Resizing ID_01199V from (64, 64) to (256, 256)
# Resizing ID_74V07L from (64, 64) to (256, 256)
# Resizing ID_3RHGRH from (64, 64) to (256, 256)
# Resizing ID_OUMADW from (64, 64) to (256, 256)
# Resizing ID_FV7067 from (64, 64) to (256, 256)
# Resizing ID_MBU56O from (64, 64) to (256, 256)
# 221/715 ━━━━━━━━━━━━━━━━━━━━ 4:31 549ms/step - accuracy: 0.7510 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_F00Y8B from (64, 64) to (256, 256)
# Resizing ID_9V5PF5 from (64, 64) to (256, 256)
# Resizing ID_C6JDIV from (64, 64) to (256, 256)
# Resizing ID_8YQGKB from (64, 64) to (256, 256)
# Resizing ID_AYZJ1B from (64, 64) to (256, 256)
# Resizing ID_DG1NN4 from (64, 64) to (256, 256)
# Resizing ID_RQPBS0 from (64, 64) to (256, 256)
# Resizing ID_TLJ6W1 from (64, 64) to (256, 256)
# 222/715 ━━━━━━━━━━━━━━━━━━━━ 4:30 549ms/step - accuracy: 0.7510 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_6HA3S7 from (64, 64) to (256, 256)
# Resizing ID_JEBEFU from (64, 64) to (256, 256)
# Resizing ID_HJ4KZ3 from (64, 64) to (256, 256)
# Resizing ID_TLQYO9 from (64, 64) to (256, 256)
# Resizing ID_EF38JH from (64, 64) to (256, 256)
# Resizing ID_A9NKDG from (64, 64) to (256, 256)
# Resizing ID_M9LUM9 from (64, 64) to (256, 256)
# Resizing ID_TQ99R3 from (64, 64) to (256, 256)
# 223/715 ━━━━━━━━━━━━━━━━━━━━ 4:29 549ms/step - accuracy: 0.7510 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_YXX78S from (64, 64) to (256, 256)
# Resizing ID_KLNW0O from (64, 64) to (256, 256)
# Resizing ID_H0I9JO from (64, 64) to (256, 256)
# Resizing ID_DOOA4F from (64, 64) to (256, 256)
# Resizing ID_VEO58W from (64, 64) to (256, 256)
# Resizing ID_SBPY21 from (64, 64) to (256, 256)
# Resizing ID_LBOQ0L from (64, 64) to (256, 256)
# Resizing ID_RTEWMP from (64, 64) to (256, 256)
# 224/715 ━━━━━━━━━━━━━━━━━━━━ 4:29 548ms/step - accuracy: 0.7510 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_IP8PX2 from (64, 64) to (256, 256)
# Resizing ID_JO3D34 from (64, 64) to (256, 256)
# Resizing ID_7URSBJ from (64, 64) to (256, 256)
# Resizing ID_70XZ3R from (64, 64) to (256, 256)
# Resizing ID_G3E8JI from (64, 64) to (256, 256)
# Resizing ID_4VGXRJ from (64, 64) to (256, 256)
# Resizing ID_M72I6S from (64, 64) to (256, 256)
# Resizing ID_3PSWXM from (64, 64) to (256, 256)
# 225/715 ━━━━━━━━━━━━━━━━━━━━ 4:28 548ms/step - accuracy: 0.7510 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_YJ7PGC from (64, 64) to (256, 256)
# Resizing ID_6OW0XM from (64, 64) to (256, 256)
# Resizing ID_ZESBFA from (64, 64) to (256, 256)
# Resizing ID_2B0ER1 from (64, 64) to (256, 256)
# Resizing ID_2JDQZ8 from (64, 64) to (256, 256)
# Resizing ID_EHQSUZ from (64, 64) to (256, 256)
# Resizing ID_76Z6PR from (64, 64) to (256, 256)
# Resizing ID_G6THKV from (64, 64) to (256, 256)
# 226/715 ━━━━━━━━━━━━━━━━━━━━ 4:27 548ms/step - accuracy: 0.7510 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_8JG5IE from (64, 64) to (256, 256)
# Resizing ID_JKQB6L from (64, 64) to (256, 256)
# Resizing ID_F5OD5M from (64, 64) to (256, 256)
# Resizing ID_DDL05C from (64, 64) to (256, 256)
# Resizing ID_WNTRZB from (64, 64) to (256, 256)
# Resizing ID_I59KHP from (64, 64) to (256, 256)
# Resizing ID_NZE9OB from (64, 64) to (256, 256)
# Resizing ID_V4XEZ7 from (64, 64) to (256, 256)
# 227/715 ━━━━━━━━━━━━━━━━━━━━ 4:27 547ms/step - accuracy: 0.7510 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_L63K6O from (64, 64) to (256, 256)
# Resizing ID_2MGU1Y from (64, 64) to (256, 256)
# Resizing ID_YJLC31 from (64, 64) to (256, 256)
# Resizing ID_H7WVJ9 from (64, 64) to (256, 256)
# Resizing ID_OJP9W1 from (64, 64) to (256, 256)
# Resizing ID_M890LV from (64, 64) to (256, 256)
# Resizing ID_KSOBEO from (64, 64) to (256, 256)
# Resizing ID_6NCUDA from (64, 64) to (256, 256)
# 228/715 ━━━━━━━━━━━━━━━━━━━━ 4:26 547ms/step - accuracy: 0.7510 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_WJ28B5 from (64, 64) to (256, 256)
# Resizing ID_0GV5VF from (64, 64) to (256, 256)
# Resizing ID_14QUMX from (64, 64) to (256, 256)
# Resizing ID_5KOFP8 from (64, 64) to (256, 256)
# Resizing ID_3RFKK9 from (64, 64) to (256, 256)
# Resizing ID_GGBDDR from (64, 64) to (256, 256)
# Resizing ID_5A38E1 from (64, 64) to (256, 256)
# Resizing ID_6KW6H0 from (64, 64) to (256, 256)
# 229/715 ━━━━━━━━━━━━━━━━━━━━ 4:25 547ms/step - accuracy: 0.7510 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_8MQWFO from (64, 64) to (256, 256)
# Resizing ID_6QOHN9 from (64, 64) to (256, 256)
# Resizing ID_J9AVRY from (64, 64) to (256, 256)
# Resizing ID_BI45LT from (64, 64) to (256, 256)
# Resizing ID_A9NPFJ from (64, 64) to (256, 256)
# Resizing ID_3GSAW1 from (64, 64) to (256, 256)
# Resizing ID_X188P5 from (64, 64) to (256, 256)
# Resizing ID_II5XRM from (64, 64) to (256, 256)
# 230/715 ━━━━━━━━━━━━━━━━━━━━ 4:25 547ms/step - accuracy: 0.7511 - balanced_f1_score: nan - loss: nan - precision_m: nan - recall_m: nanResizing ID_FB19D4 from (64, 64) to (256, 256)
# Resizing ID_61PABR from (64, 64) to (256, 256)
# Resizing ID_YQAS6L from (64, 64) to (256, 256)
# Resizing ID_RIHI53 from (64, 64) to (256, 256)
# Resizing ID_T8DR5W from (64, 64) to (256, 256)
# Resizing ID_ZB9N32 from (64, 64) to (256, 256)
# Resizing ID_J38QYM from (64, 64) to (256, 256)
# Resizing ID_NVQ2VF from (64, 64) to (256, 256)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-89115620.py in <cell line: 0>()
#     504 # Train model
#     505 print("Starting training...")
# --> 506 history = model.fit(
#     507     train_gen,
#     508     validation_data=val_gen,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369                 for step, iterator in epoch_iterator:
#     370                     callbacks.on_train_batch_begin(step)
# --> 371                     logs = self.train_function(iterator)
#     372                     callbacks.on_train_batch_end(step, logs)
#     373                     if self.stop_training:
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     217                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218             ):
# --> 219                 opt_outputs = multi_step_on_iterator(iterator)
#     220                 if not opt_outputs.has_value():
#     221                     raise StopIteration
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1681     cancellation_context = cancellation.context()
#    1682     if cancellation_context is None:
# -> 1683       outputs = execute.execute(
#    1684           name.decode("utf-8"),
#    1685           num_outputs=num_outputs,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
